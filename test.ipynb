# %%
import wizzair as wz
import pandas as pd
# Out:
# 2025-02-06 16:20:00.877 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-02-06 16:20:00.912 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-02-06 16:20:00.966 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
outbound, returns = wz._fetch_timetable("LON", "DEB", pd.to_datetime("2024-12-25"), pd.to_datetime("2025-01-15"))
# Out:
# 2025-02-06 16:20:01.055 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 outbound, returns = wz._fetch_timetable("LON", "DEB", pd.to_datetime("2024-12-25"), pd.to_datetime("2025-01-15"))
#
# File c:\Users\osz.oliver\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:218, in CachedFunc.__call__(self, *args, **kwargs)
#     215     else:
#     216         spinner_message = f"Running `{name}(...)`."
# --> 218 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File c:\Users\osz.oliver\AppData\Local\Programs\Python\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:260, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
# ...

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   departureStation  9 non-null      object
#  1   arrivalStation    9 non-null      object
#  2   departureDate     9 non-null      datetime64[ns]
#  3   price             9 non-null      float64
#  4   departureDates    9 non-null      object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 492.0+ bytes
